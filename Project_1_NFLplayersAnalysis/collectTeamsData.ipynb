# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime

# Import API key
from api_keys import sport_key

# %%
data_year = '2018'
standings_url = f"http://api.sportradar.us/nfl/official/trial/v5/en/seasons/{data_year}/standings.json?"

standings_query_url = f"{standings_url}api_key={sport_key}"

standings_response = requests.get(standings_query_url)
standings_json = standings_response.json()

# %%
teams = []
team_data = []

for conference in range(len(standings_json['conferences'])):

    for division in range(len(standings_json['conferences'][conference])):
        
        for team in range(len(standings_json['conferences'][conference]['divisions'][division])):
            
            teams.append({
            'Season_Year'   : standings_json['season']['year'],
            'Season_Type'   : standings_json['season']['type'],
            'Conference'    : standings_json['conferences'][conference]['name'],
            'Division'      : standings_json['conferences'][conference]['divisions'][division]['name'],
            'Team_Name'     : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['name'],
            'Team_ID'       : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['id'],
            'Wins'          : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['wins'],
            'Losses'        : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['losses'],         
            'Ties'          : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['ties'],
            'Win_pct'       : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['win_pct'],
            'Points_for'    : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['points_for'],
            'Points_against': standings_json['conferences'][conference]['divisions'][division]['teams'][team]['points_against'],
            'Points_rank'   : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['points_rank'],
            'Touchdown_diff': standings_json['conferences'][conference]['divisions'][division]['teams'][team]['touchdown_diff'],
        })
            
teams_df = pd.DataFrame(teams)
teams_df.to_csv(f"Resources/standings_{data_year}.csv", index=False)
teams_df.groupby(['Conference','Division', 'Team_Name']).mean()
# Out:
#                                  Losses  Points_against  Points_for  \
# Conference Division  Team_Name
# AFC        AFC East  Bills           10             374         269
#                      Dolphins         9             433         319
#                      Jets            12             441         333
#                      Patriots         5             325         436
#            AFC North Bengals         10             455         368
#                      Browns           8             392         359
#                      Ravens           6             287         389
#                      Steelers         6             360         428
#            AFC South Colts            6             344         433
#                      Jaguars         11             316         245
#                      Texans           5             316         402
#                      Titans           7             303         310
#            AFC West  Broncos         10             349         329
#                      Chargers         4             329         428
#                      Chiefs           4             421         565
#                      Raiders         12             467         290
# NFC        NFC East  Cowboys          6             324         339
#                      Eagles           7             348         367
#                      Giants          11             412         369
#                      Redskins         9             359         281
#            NFC North Bears            4             283         421
#                      Lions           10             360         324
#                      Packers          9             400         376
#                      Vikings          7             341         360
#            NFC South Buccaneers      11             464         396
#                      Falcons          9             423         414
#                      Panthers         9             382         376
#                      Saints           3             353         504
#            NFC West  49ers           12             435         342
#                      Cardinals       13             425         225
#                      Rams             3             384         527
#                      Seahawks         6             347         428
#
#                                  Points_rank  Season_Year  Ties  \
# Conference Division  Team_Name
# AFC        AFC East  Bills                48         2018     0
#                      Dolphins             53         2018     0
#                      Jets                 52         2018     0
#                      Patriots             11         2018     0
#            AFC North Bengals              47         2018     0
#                      Browns               41         2018     1
#                      Ravens               15         2018     0
#                      Steelers             22         2018     1
#            AFC South Colts                15         2018     0
#                      Jaguars              35         2018     0
#                      Texans               15         2018     0
#                      Titans               30         2018     0
#            AFC West  Broncos              37         2018     0
#                      Chargers             14         2018     0
#                      Chiefs               25         2018     0
#                      Raiders              60         2018     0
# NFC        NFC East  Cowboys              28         2018     0
#                      Eagles               30         2018     0
#                      Giants               39         2018     0
#                      Redskins             44         2018     0
#            NFC North Bears                10         2018     0
#                      Lions                41         2018     0
#                      Packers              36         2018     1
#                      Vikings              28         2018     1
#            NFC South Buccaneers           43         2018     0
#                      Falcons              35         2018     0
#                      Panthers             33         2018     0
#                      Saints               17         2018     0
#            NFC West  49ers                49         2018     0
#                      Cardinals            58         2018     0
#                      Rams                 22         2018     0
#                      Seahawks             17         2018     0
#
#                                  Touchdown_diff  Win_pct  Wins
# Conference Division  Team_Name
# AFC        AFC East  Bills                  -15    0.375     6
#                      Dolphins               -14    0.438     7
#                      Jets                   -15    0.250     4
#                      Patriots                15    0.688    11
#            AFC North Bengals                 -6    0.375     6
#                      Browns                   1    0.469     7
#                      Ravens                   8    0.625    10
#                      Steelers                12    0.594     9
#            AFC South Colts                   15    0.625    10
#                      Jaguars                 -9    0.313     5
#                      Texans                   6    0.688    11
#                      Titans                   2    0.563     9
#            AFC West  Broncos                  0    0.375     6
#                      Chargers                13    0.750    12
#                      Chiefs                  20    0.750    12
#                      Raiders                -26    0.250     4
# NFC        NFC East  Cowboys                  1    0.625    10
#                      Eagles                   4    0.563     9
#                      Giants                  -6    0.313     5
#                      Redskins               -14    0.438     7
#            NFC North Bears                   20    0.750    12
#                      Lions                   -9    0.375     6
#                      Packers                 -6    0.406     6
#                      Vikings                  8    0.531     8
#            NFC South Buccaneers              -8    0.313     5
#                      Falcons                 -3    0.438     7
#                      Panthers                 0    0.438     7
#                      Saints                  17    0.813    13
#            NFC West  49ers                  -17    0.250     4
#                      Cardinals              -23    0.188     3
#                      Rams                    16    0.813    13
#                      Seahawks                13    0.625    10

# %%
all_teams_season = []

for team in range(len(teams_df)):
    print(f"Loop #{team} Collecting data for {teams_df.Team_Name[team]} team")
     
    season_url = f"http://api.sportradar.us/nfl/official/trial/v5/en/seasons/{data_year}/REG/teams/{teams_df.Team_ID[team]}/statistics.json?"
    season_query_url = f"{season_url}api_key={sport_key}"
    season_response = requests.get(season_query_url)
    all_teams_season.append(season_response.json())
    
    time.sleep(1)
            
print("------------------")
print("Process Completed")

all_teams_season_df = pd.DataFrame(all_teams_season)
all_teams_season_df.to_csv(f"Resources/all_teams_season_{data_year}.csv", index=False)
# Out:
# Loop #0 Collecting data for Patriots team
# Loop #1 Collecting data for Dolphins team
# Loop #2 Collecting data for Bills team
# Loop #3 Collecting data for Jets team
# Loop #4 Collecting data for Ravens team
# Loop #5 Collecting data for Steelers team
# Loop #6 Collecting data for Browns team
# Loop #7 Collecting data for Bengals team
# Loop #8 Collecting data for Texans team
# Loop #9 Collecting data for Colts team
# Loop #10 Collecting data for Titans team
# Loop #11 Collecting data for Jaguars team
# Loop #12 Collecting data for Chiefs team
# Loop #13 Collecting data for Chargers team
# Loop #14 Collecting data for Broncos team
# Loop #15 Collecting data for Raiders team
# Loop #16 Collecting data for Cowboys team
# Loop #17 Collecting data for Eagles team
# Loop #18 Collecting data for Redskins team
# Loop #19 Collecting data for Giants team
# Loop #20 Collecting data for Bears team
# Loop #21 Collecting data for Vikings team
# Loop #22 Collecting data for Packers team
# Loop #23 Collecting data for Lions team
# Loop #24 Collecting data for Saints team
# Loop #25 Collecting data for Falcons team
# Loop #26 Collecting data for Panthers team
# Loop #27 Collecting data for Buccaneers team
# Loop #28 Collecting data for Rams team
# Loop #29 Collecting data for Seahawks team
# Loop #30 Collecting data for 49ers team
# Loop #31 Collecting data for Cardinals team
# ------------------
# Process Completed

# %%
all_teams_season_df['players'][0][0].keys()
# Out:
# dict_keys(['id', 'name', 'jersey', 'reference', 'position', 'sr_id', 'games_played', 'games_started'])

# %%
#all_teams_season_df['players'][30][0].keys()

players = []

for team in range(len(all_teams_season_df['name'])):
    for player in range(len(all_teams_season_df['players'][team])):
            if 'position' in all_teams_season_df['players'][team][player].keys():
                  players.append({
                    'Team_name'  : all_teams_season_df['name'][team],
                    'Season_Year': all_teams_season_df['season'][0]['year'],
                    'Player_Name': all_teams_season_df['players'][team][player]['name'],
                    'Player_ID'  : all_teams_season_df['players'][team][player]['id'],
                    'Position'   : all_teams_season_df['players'][team][player]['position'],
                    })

all_players_df = pd.DataFrame(players)
all_players_df.to_csv(f"Resources/all_players_{data_year}.csv", index=False)
all_players_df
# Out:
#                                  Player_ID          Player_Name Position  \
# 0     021fddc1-4ba1-4bcb-9f40-347a0be8866a        Christian Sam       LB
# 1     072ec285-1430-48d4-9342-5a1b9af527f3      Adrian Clayborn       DE
# 2     0861a57d-b468-4c21-ba3a-7523b6838ed0         Lawrence Guy       DT
# 3     0ad845ff-44e8-4576-bc91-61b557e06f05         Kyle Van Noy      OLB
# 4     132721b4-fd32-4795-b214-ab4baaaceb3a        Bennie Fowler       WR
# 5     1376da0d-0448-4a37-bd99-842c4580eeda          Sony Michel       RB
# 6     173831a7-d33d-4d2a-8dd9-4e36182e23cc          Trent Brown        T
# 7     18264a0b-cb51-487a-b2cc-f9258f0325f6         Trent Harris       DE
# 8     18f0bd30-1432-4fae-9cb4-c212bad6d0bb      Braxton Berrios       WR
# 9     2142a164-48ad-47d6-bb27-0bc58c6b2e62       Rob Gronkowski       TE
# 10    2516f9e7-9927-409d-adbe-b32d680ae71d        Deatrich Wise       DE
# 11    25a4ae85-e94b-4db1-b939-4c96f24ead11           John Simon       DE
# 12    27b1ba46-842b-4bca-a434-56c60102c1b5          Isaiah Wynn        T
# 13    2bb70d56-a79a-4fa1-ae37-99858a3ffd55       Julian Edelman       WR
# 14    30b045f1-b8e4-4ae9-b062-5181847b508c            Eric Rowe       CB
# 15    3164fc4b-b2ae-43b3-9ff1-1d5f744b9f88     Ja'Whaun Bentley      ILB
# 16    342fe758-e8d0-4baf-af71-1fa568197837          Cyrus Jones       CB
# 17    36bb2c46-33d3-4e86-bb12-63b658cf8f7f           Matt Tobin        G
# 18    396c3f6d-db27-431e-a3fa-e5a6c12eba7a       Darren Andrews       WR
# 19    39f70428-a78a-494c-8676-438d953c289e          James White       RB
# 20    3a3a9ed8-e941-49cf-bc32-331424d0bd42         Cole Croston        T
# 21    3c151ffc-4fd3-4785-96e0-3a257e99706a        Obi Melifonwu       DB
# 22    40b8fa44-b289-42dd-9606-a1ae30adc7bc            Ryan Izzo       TE
# 23    41c44740-d0f6-44ab-8347-3b5d515e5ecf            Tom Brady       QB
# 24    433a368a-b67c-4c84-ac59-5addd32bb36a          Ulrick John        T
# 25    45039bcf-634a-48a7-8102-f0131491cf66      LaAdrian Waddle        T
# 26    4ee0937c-1250-4456-93d4-2d6afa064d5a           Joe Thuney        G
# 27    537c88d4-c403-43f4-94a1-fdccea0ee24a       Jonathan Jones       CB
# 28    54814199-dd18-408f-9dc4-ce59a121431b          Adam Butler       DT
# 29    57deb6ba-ce26-4ccc-a859-adf0564fb78e         Trey Flowers       DE
# ...                                    ...                  ...      ...
# 2237  b399ac02-6b52-4ae9-8eb0-7b3fffc29eea        Gerald Hodges      ILB
# 2238  b44773b9-af17-4d6c-a453-132e20849712     Jermaine Gresham       TE
# 2239  b612c556-1285-405f-9294-733f0302869e        Benson Mayowa       DE
# 2240  b6a61b38-5cfa-46eb-b1c5-b0255d7ebaf5     Larry Fitzgerald       WR
# 2241  b6fe2eb8-3692-450a-98b3-11e47c8b6711          Justin Pugh        G
# 2242  bd49c4a4-1314-45e1-bff5-fc67ba41d1dd         Matt McCrane        K
# 2243  c43cf6a1-8faa-4f95-aa2a-f1aac3ffe103        John Phillips       TE
# 2244  c6c63d67-4913-497f-a17c-55c72cbe5b9b        Rees Odhiambo        T
# 2245  c9b212ad-7893-4b0d-9d65-38b283894a5a        Pasoni Tasini       DT
# 2246  cc3640b0-7560-431f-84ab-599e9dc8cac6         Sam Bradford       QB
# 2247  cd0f4ef0-9914-4125-be4d-804a72350ceb        Zane Gonzalez        K
# 2248  cdb10720-0d41-4cb6-9fb8-c00713754a1e     Brandon Williams       CB
# 2249  d1ac1143-9b14-41b7-be88-6b094592a3dd  Thurston Armbrister      OLB
# 2250  d3c47b87-1554-4afe-ab8f-d5e801706fc3      Quinten Rollins       CB
# 2251  d46e3db5-f89f-4211-b8a7-baeb1a35df46         Oday Aboushi        G
# 2252  d5ba025d-5e9d-452d-8b86-f68a3bff5e22       Dontae Johnson       CB
# 2253  d8d9b161-7ef4-42bf-89b7-7edf806a0ad1        Chase Edmonds       RB
# 2254  d954bad7-541b-43d5-9918-ef1cead10b13        Joe Barksdale        T
# 2255  e0a27785-ab78-4d51-8a8e-8fb9896956fd        Malachi Dupre       WR
# 2256  e0a63251-5428-43a1-88c1-c000215ac5ce      Derrick Coleman       FB
# 2257  e1235f1e-26ce-438c-8168-3b1ded4ab893         Mike Glennon       QB
# 2258  e187574f-622f-4477-a61a-edec81adff2f       Charles Kanoff       QB
# 2259  e1f9e986-6deb-4302-8478-eb64abe7aa24        Colby Gossett        G
# 2260  e2ba47b5-f503-42fc-86d2-2f6061551a30        Daniel Munyer        C
# 2261  e4a401ce-3740-4e6b-8dcf-f2b41a3beeb9        Rodney Gunter       DT
# 2262  e5247e5f-c4af-4a9b-8c7c-da75ef7fbf8d          Phil Dawson        K
# 2263  eb2c9e63-3a33-441e-aa95-462eaf97a371      Ifeadi Odenigbo       DE
# 2264  ebcd87ce-218c-4144-810b-921c2f59d6e8       Christian Kirk       WR
# 2265  edaad8e3-62cd-4715-b225-0010ee9825a0             Andy Lee        P
# 2266  ee399a97-6868-4db1-9381-09073914c2d6       Haason Reddick      ILB
#
#       Season_Year  Team_name
# 0            2018   Patriots
# 1            2018   Patriots
# 2            2018   Patriots
# 3            2018   Patriots
# 4            2018   Patriots
# 5            2018   Patriots
# 6            2018   Patriots
# 7            2018   Patriots
# 8            2018   Patriots
# 9            2018   Patriots
# 10           2018   Patriots
# 11           2018   Patriots
# 12           2018   Patriots
# 13           2018   Patriots
# 14           2018   Patriots
# 15           2018   Patriots
# 16           2018   Patriots
# 17           2018   Patriots
# 18           2018   Patriots
# 19           2018   Patriots
# 20           2018   Patriots
# 21           2018   Patriots
# 22           2018   Patriots
# 23           2018   Patriots
# 24           2018   Patriots
# 25           2018   Patriots
# 26           2018   Patriots
# 27           2018   Patriots
# 28           2018   Patriots
# 29           2018   Patriots
# ...           ...        ...
# 2237         2018  Cardinals
# 2238         2018  Cardinals
# 2239         2018  Cardinals
# 2240         2018  Cardinals
# 2241         2018  Cardinals
# 2242         2018  Cardinals
# 2243         2018  Cardinals
# 2244         2018  Cardinals
# 2245         2018  Cardinals
# 2246         2018  Cardinals
# 2247         2018  Cardinals
# 2248         2018  Cardinals
# 2249         2018  Cardinals
# 2250         2018  Cardinals
# 2251         2018  Cardinals
# 2252         2018  Cardinals
# 2253         2018  Cardinals
# 2254         2018  Cardinals
# 2255         2018  Cardinals
# 2256         2018  Cardinals
# 2257         2018  Cardinals
# 2258         2018  Cardinals
# 2259         2018  Cardinals
# 2260         2018  Cardinals
# 2261         2018  Cardinals
# 2262         2018  Cardinals
# 2263         2018  Cardinals
# 2264         2018  Cardinals
# 2265         2018  Cardinals
# 2266         2018  Cardinals
#
# [2267 rows x 5 columns]
